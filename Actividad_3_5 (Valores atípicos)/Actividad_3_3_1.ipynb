# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastianCH77/UF3/blob/main/Actividad_3_5%20(Valores%20at%C3%ADpicos)/Actividad_3_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde COLAB
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cbfe4810-b01e-4a38-b788-22b9086a9691" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbfe4810-b01e-4a38-b788-22b9086a9691">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo .csv sin indice
data = pd.read_csv('Ventas_totales_sin_nulos.csv')

# %%
#Verificamos información
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0.1                         65 non-null     int64
#  1   Unnamed: 0                           65 non-null     int64
#  2   indice_tiempo                        65 non-null     object
#  3   ventas_precios_corrientes            65 non-null     float64
#  4   ventas_precios_constantes            65 non-null     float64
#  5   ventas_totales_canal_venta           65 non-null     float64
#  6   salon_ventas                         65 non-null     float64
#  7   canales_on_line                      65 non-null     float64
#  8   ventas_totales_medio_pago            65 non-null     float64
#  9   efectivo                             65 non-null     float64
#  10  tarjetas_debito                      65 non-null     float64
# ...

# %%
data
# Out:
#     Unnamed: 0.1  Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0              0           0    01/01/2017                    27858.9
# 1              1           1    01/02/2017                    25994.2
# 2              2           2    01/03/2017                    27780.0
# 3              3           3    01/04/2017                    29134.3
# 4              4           4    01/05/2017                    27969.0
# ..           ...         ...           ...                        ...
# 60            60          60    01/01/2022                   154517.1
# 61            61          61    01/02/2022                   152202.6
# 62            62          62    01/03/2022                       16.5
# 63            63          63    01/04/2022                   177148.1
# 64            64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# ...

# %%
data = data.drop('Unnamed: 0.1', axis=1)

# %%
data = data.drop('Unnamed: 0', axis=1)

# %%
data
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    25222.6
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Verificamos información
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   indice_tiempo                        65 non-null     object
#  1   ventas_precios_corrientes            65 non-null     float64
#  2   ventas_precios_constantes            65 non-null     float64
#  3   ventas_totales_canal_venta           65 non-null     float64
#  4   salon_ventas                         65 non-null     float64
#  5   canales_on_line                      65 non-null     float64
#  6   ventas_totales_medio_pago            65 non-null     float64
#  7   efectivo                             65 non-null     float64
#  8   tarjetas_debito                      65 non-null     float64
#  9   tarjetas_credito                     65 non-null     float64
#  10  otros_medios                         65 non-null     float64
# ...

# %%
#Creo 2 dataframes para poder procesar los outliers
cuantitativas= data.iloc[ : , 1:24 ]
cualitativas= data.iloc[ : , [0] ]

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize = (15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Datframe")
plt.show() #Dibujamos el diagrama

# %% [markdown]
# ## Procedimiento "Desviación Estandar" Para eliminar Outliers en mi DataFrame

# %%
#Encuentro los valores extremos
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Límite superior permitido", Limite_Superior)
print("Límite inferior permitido", Limite_Inferior)
# Out:
# Límite superior permitido ventas_precios_corrientes              1.930929e+05
# ventas_precios_constantes              3.048357e+04
# ventas_totales_canal_venta             2.074407e+08
# salon_ventas                           1.526047e+08
# canales_on_line                        7.623053e+06
# ventas_totales_medio_pago              2.059531e+08
# efectivo                               6.191160e+07
# tarjetas_debito                        4.283255e+07
# tarjetas_credito                       6.246322e+07
# otros_medios                           1.048925e+07
# ventas_totales_grupo_articulos         2.059531e+08
# subtotal_ventas_alimentos_bebidas      1.044082e+08
# bebidas                                2.392969e+07
# almacen                                5.498569e+07
# panaderia                              4.912072e+06
# lacteos                                2.130859e+07
# carnes                                 2.509435e+07
# verduleria_fruteria                    7.570093e+06
# ...

# %%
#Verificamos outliers
data2=cuantitativas[(y>Limite_Superior)|(y<Limite_Inferior)]
data2
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 60                        NaN                        NaN
# 61                        NaN                        NaN
# 62                        NaN                        NaN
# 63                        NaN                        NaN
# 64                        NaN                        NaN
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                          NaN           NaN              NaN
# 1                          NaN           NaN              NaN
# 2                          NaN           NaN              NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    25222.6
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                   177148.1                    24140.5
# 64                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07   27591730.13     2.671420e+05
# 1                 2.599420e+07   25749179.40     2.450208e+05
# 2                 2.778001e+07   27472228.72     3.077778e+05
# ...

# %%
#Corroboramos valores nulos del Datframe4
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# otros                                  0
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del DataFrame
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    25222.6
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                   177148.1                    24140.5
# 64                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07   27591730.13     2.671420e+05
# 1                 2.599420e+07   25749179.40     2.450208e+05
# 2                 2.778001e+07   27472228.72     3.077778e+05
# ...

# %% [markdown]
# ## Procedimiento CUANTILES para sustituir Outliers en DtaFrame

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido ventas_precios_corrientes              1.703611e+05
# ventas_precios_constantes              3.036050e+04
# ventas_totales_canal_venta             1.875116e+08
# salon_ventas                           1.251630e+08
# canales_on_line                        9.196781e+06
# ventas_totales_medio_pago              1.875116e+08
# efectivo                               5.942022e+07
# tarjetas_debito                        3.849177e+07
# tarjetas_credito                       5.984382e+07
# otros_medios                           1.061843e+07
# ventas_totales_grupo_articulos         1.875116e+08
# subtotal_ventas_alimentos_bebidas      8.486397e+07
# bebidas                                2.282518e+07
# almacen                                5.015298e+07
# panaderia                              4.488895e+06
# lacteos                                1.938669e+07
# carnes                                 2.390920e+07
# verduleria_fruteria                    7.832862e+06
# ...

# %%
#Obtenemos datos limpios del DataFrame
data3_iqr= cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    25222.6
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                        NaN                    24140.5
# 64                        NaN                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07   27591730.13     2.671420e+05
# 1                 2.599420e+07   25749179.40     2.450208e+05
# 2                 2.778001e+07   27472228.72     3.077778e+05
# ...

# %%
#Corroboramos valores nulos del Datframe Limpio
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# ventas_precios_corrientes              2
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           2
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        2
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      3
# bebidas                                0
# almacen                                0
# panaderia                              1
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         3
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# otros                                  3
# ...

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del DataFrame
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#     ventas_precios_corrientes  ventas_precios_constantes  \
# 0                     27858.9                    27477.3
# 1                     25994.2                    25223.4
# 2                     27780.0                    26334.3
# 3                     29134.3                    27045.9
# 4                     27969.0                    25631.9
# ..                        ...                        ...
# 60                   154517.1                    25222.6
# 61                   152202.6                    23802.1
# 62                       16.5                    24612.4
# 63                    64794.6                    24140.5
# 64                    64794.6                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 2.785887e+07   27591730.13     2.671420e+05
# 1                 2.599420e+07   25749179.40     2.450208e+05
# 2                 2.778001e+07   27472228.72     3.077778e+05
# ...

# %%
#Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    25222.6
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                    64794.6                    24140.5
# 64    01/05/2022                    64794.6                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios_iqr.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files


files.download("Datos_limpios_iqr.csv")

# %% [markdown]
# ## UNIR PARA EL MÉTODO DE DESVIACIÓN

# %%
#Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios_desvest = pd.concat([cualitativas, data_clean], axis=1)
Datos_limpios_desvest
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    25222.6
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Convertir DataFrame a CSV
Datos_limpios_desvest.to_csv("Datos_limpios_desv.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files


files.download("Datos_limpios_desv.csv")
